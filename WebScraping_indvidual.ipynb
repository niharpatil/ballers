# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
r = requests.get("https://www.basketball-reference.com/players/h/hardeja01.html")

# %%
soup = BeautifulSoup(r.text, "html5lib")
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/bbr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
#   <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201803141" rel="dns-prefetch"/>
#   <!-- no:cookie fast load the css.           -->
#   <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
#   <link crossorigin="" href="https://d2cwpp38twqe55.cloudfront.net" rel="preconnect"/>
#   <style>
# ...

# %%
height = soup.find(itemprop="height").getText().split('-')
int(height[0])*12 + int(height[1])
# Out:
# 77

# %%
weight = soup.find(itemprop="weight").getText()[:-2]
print(int(weight))
# Out:
# 220

# %%
name = soup.find('h1', itemprop='name').getText()
# Out:
# 'James Harden'

# %%
draft_pos = soup.find('div', itemtype='https://schema.org/Person' )
draft_year_blob = draft_pos.find('a', text=re.compile('Draft'))
draft_pos = draft_pos.find(text=re.compile('overall'))
draft_pos
# Out:
# ', 1st round (3rd pick, 3rd overall), '

# %%
    draft_re = re.compile("\d+")
    t = draft_re.findall(draft_pos)
    pick_round = int(t[0])
    pick_in_round = int(t[1])
    pick_overall = int(t[2])
    draft_year = int(draft_re.findall(draft_year_blob.getText())[0])
    print(pick_in_round)
    print(draft_year)
# Out:
# 3
# 2009
